# %%
### Write some markdown to explain that this notebook will be mainly used for the capstone project.

# %% [markdown]
# This notebook will be mainly used for IBM Applied Data Science Capstone course on Coursera.

# %% [markdown]
# Objectives is to predict the possibility of an accident to occur and it's impact due to several factors

# %%
import pandas as pd ### Import the pandas library as pd.
import numpy as np ### Import the Numpy library as np.

# %%
### Print the statement: Hello Capstone Project Course!
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
